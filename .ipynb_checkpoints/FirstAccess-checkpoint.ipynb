# %%
import pandas as pd
import oandapyV20

# %%
from oandapyV20 import API
import oandapyV20.endpoints.accounts as accounts

# %%
accountID = '101-001-5729740-011'
access_token = '10205fa114f1778b74e3949320bcb275-b8fea4f40cc338ae9d44bd54f3154843'
client = API(access_token=access_token)

# %%
r = accounts.AccountDetails(accountID=accountID)
client.request(r)
print(r.response)
# Out:
# {'account': {'guaranteedStopLossOrderMode': 'DISABLED', 'id': '101-001-5729740-011', 'createdTime': '2018-02-22T11:49:53.736708406Z', 'currency': 'USD', 'createdByUserID': 5729740, 'alias': 'Test 5', 'marginRate': '0.02', 'hedgingEnabled': False, 'lastTransactionID': '210', 'balance': '1028.8820', 'openTradeCount': 1, 'openPositionCount': 1, 'pendingOrderCount': 0, 'pl': '17.7424', 'resettablePL': '17.7424', 'resettablePLTime': '0', 'financing': '-0.7904', 'commission': '0.0000', 'guaranteedExecutionFees': '0.0000', 'orders': [], 'positions': [{'instrument': 'EUR_GBP', 'long': {'units': '0', 'pl': '0.0000', 'resettablePL': '0.0000', 'financing': '0.0000', 'guaranteedExecutionFees': '0.0000', 'unrealizedPL': '0.0000'}, 'short': {'units': '0', 'pl': '-9.7123', 'resettablePL': '-9.7123', 'financing': '-0.0956', 'guaranteedExecutionFees': '0.0000', 'unrealizedPL': '0.0000'}, 'pl': '-9.7123', 'resettablePL': '-9.7123', 'financing': '-0.0956', 'commission': '0.0000', 'guaranteedExecutionFees': '0.0000', 'unrealizedPL': '0.0000', 'marginUsed': '0.0000'}, {'instrument': 'EUR_JPY', 'long': {'units': '0', 'pl': '-8.4946', 'resettablePL': '-8.4946', 'financing': '-0.1239', 'guaranteedExecutionFees': '0.0000', 'unrealizedPL': '0.0000'}, 'short': {'units': '0', 'pl': '6.5893', 'resettablePL': '6.5893', 'financing': '-0.0827', 'guaranteedExecutionFees': '0.0000', 'unrealizedPL': '0.0000'}, 'pl': '-1.9053', 'resettablePL': '-1.9053', 'financing': '-0.2066', 'commission': '0.0000', 'guaranteedExecutionFees': '0.0000', 'unrealizedPL': '0.0000', 'marginUsed': '0.0000'}, {'instrument': 'AUD_USD', 'long': {'units': '1000', 'averagePrice': '0.72761', 'pl': '9.0600', 'resettablePL': '9.0600', 'financing': '-0.4413', 'guaranteedExecutionFees': '0.0000', 'tradeIDs': ['209'], 'unrealizedPL': '2.6300'}, 'short': {'units': '0', 'pl': '20.3000', 'resettablePL': '20.3000', 'financing': '-0.0469', 'guaranteedExecutionFees': '0.0000', 'unrealizedPL': '0.0000'}, 'pl': '29.3600', 'resettablePL': '29.3600', 'financing': '-0.4882', 'commission': '0.0000', 'guaranteedExecutionFees': '0.0000', 'unrealizedPL': '2.6300', 'marginUsed': '21.9090'}], 'trades': [{'id': '209', 'instrument': 'AUD_USD', 'price': '0.72761', 'openTime': '2018-08-24T08:00:04.927036334Z', 'initialUnits': '1000', 'initialMarginRequired': '21.8262', 'state': 'OPEN', 'currentUnits': '1000', 'realizedPL': '0.0000', 'financing': '0.0000', 'clientExtensions': {'id': '207110996', 'tag': '200', 'comment': 'Bought Here'}, 'unrealizedPL': '2.6300', 'marginUsed': '21.9090'}], 'unrealizedPL': '2.6300', 'NAV': '1031.5120', 'marginUsed': '21.9090', 'marginAvailable': '1009.6030', 'positionValue': '730.3000', 'marginCloseoutUnrealizedPL': '2.6900', 'marginCloseoutNAV': '1031.5720', 'marginCloseoutMarginUsed': '21.9090', 'marginCloseoutPositionValue': '730.3000', 'marginCloseoutPercent': '0.01062', 'withdrawalLimit': '1009.6030', 'marginCallMarginUsed': '21.9090', 'marginCallPercent': '0.02124'}, 'lastTransactionID': '210'}

# %%
pd.DataFrame(r.response)
# Out:
#                                                                        account  \
# NAV                                                                  1031.5120
# alias                                                                   Test 5
# balance                                                              1028.8820
# commission                                                              0.0000
# createdByUserID                                                        5729740
# createdTime                                     2018-02-22T11:49:53.736708406Z
# currency                                                                   USD
# financing                                                              -0.7904
# guaranteedExecutionFees                                                 0.0000
# guaranteedStopLossOrderMode                                           DISABLED
# hedgingEnabled                                                           False
# id                                                         101-001-5729740-011
# lastTransactionID                                                          210
# marginAvailable                                                      1009.6030
# marginCallMarginUsed                                                   21.9090
# marginCallPercent                                                      0.02124
# marginCloseoutMarginUsed                                               21.9090
# marginCloseoutNAV                                                    1031.5720
# marginCloseoutPercent                                                  0.01062
# marginCloseoutPositionValue                                           730.3000
# marginCloseoutUnrealizedPL                                              2.6900
# marginRate                                                                0.02
# marginUsed                                                             21.9090
# openPositionCount                                                            1
# openTradeCount                                                               1
# orders                                                                      []
# pendingOrderCount                                                            0
# pl                                                                     17.7424
# positionValue                                                         730.3000
# positions                    [{'instrument': 'EUR_GBP', 'long': {'units': '...
# resettablePL                                                           17.7424
# resettablePLTime                                                             0
# trades                       [{'id': '209', 'instrument': 'AUD_USD', 'price...
# unrealizedPL                                                            2.6300
# withdrawalLimit                                                      1009.6030
#
#                             lastTransactionID
# NAV                                       210
# alias                                     210
# balance                                   210
# commission                                210
# createdByUserID                           210
# createdTime                               210
# currency                                  210
# financing                                 210
# guaranteedExecutionFees                   210
# guaranteedStopLossOrderMode               210
# hedgingEnabled                            210
# id                                        210
# lastTransactionID                         210
# marginAvailable                           210
# marginCallMarginUsed                      210
# marginCallPercent                         210
# marginCloseoutMarginUsed                  210
# marginCloseoutNAV                         210
# marginCloseoutPercent                     210
# marginCloseoutPositionValue               210
# marginCloseoutUnrealizedPL                210
# marginRate                                210
# marginUsed                                210
# openPositionCount                         210
# openTradeCount                            210
# orders                                    210
# pendingOrderCount                         210
# pl                                        210
# positionValue                             210
# positions                                 210
# resettablePL                              210
# resettablePLTime                          210
# trades                                    210
# unrealizedPL                              210
# withdrawalLimit                           210

# %%
r.response['prices']
# Out:
# [{'asks': [{'liquidity': 10000000, 'price': '1.13423'}],
#   'bids': [{'liquidity': 10000000, 'price': '1.13409'}],
#   'closeoutAsk': '1.13438',
#   'closeoutBid': '1.13394',
#   'instrument': 'EUR_USD',
#   'quoteHomeConversionFactors': {'negativeUnits': '1.00000000',
#    'positiveUnits': '1.00000000'},
#   'status': 'tradeable',
#   'time': '2018-08-15T02:04:05.757475482Z',
#   'tradeable': True,
#   'type': 'PRICE',
#   'unitsAvailable': {'default': {'long': '44048', 'short': '44048'},
#    'openOnly': {'long': '44048', 'short': '44048'},
#    'reduceFirst': {'long': '44048', 'short': '44048'},
#    'reduceOnly': {'long': '0', 'short': '0'}}},
#  {'asks': [{'liquidity': 10000000, 'price': '126.287'}],
#   'bids': [{'liquidity': 10000000, 'price': '126.269'}],
#   'closeoutAsk': '126.287',
#   'closeoutBid': '126.269',
#   'instrument': 'EUR_JPY',
#   'quoteHomeConversionFactors': {'negativeUnits': '0.00898198',
#    'positiveUnits': '0.00898085'},
#   'status': 'tradeable',
#   'time': '2018-08-15T02:04:12.340021272Z',
#   'tradeable': True,
#   'type': 'PRICE',
#   'unitsAvailable': {'default': {'long': '22024', 'short': '22024'},
#    'openOnly': {'long': '22024', 'short': '22024'},
#    'reduceFirst': {'long': '22024', 'short': '22024'},
#    'reduceOnly': {'long': '0', 'short': '0'}}}]
